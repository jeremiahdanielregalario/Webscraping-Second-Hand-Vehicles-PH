# %% [markdown]
# # Web Scraping

# %% [markdown]
# REGALARIO, Jeremiah Daniel A.

# %% [markdown]
# Assigned Website: Automart.ph
#
# Assigned Bank: PSBank

# %% [markdown]
# ## PSBank

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install tabula
# !pip install tabula-py
# Out:
# Requirement already satisfied: tabula in /usr/local/lib/python3.10/dist-packages (1.0.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tabula) (67.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tabula) (1.25.2)
# Requirement already satisfied: tabula-py in /usr/local/lib/python3.10/dist-packages (2.9.3)
# Requirement already satisfied: pandas>=0.25.3 in /usr/local/lib/python3.10/dist-packages (from tabula-py) (2.0.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tabula-py) (1.25.2)
# Requirement already satisfied: distro in /usr/lib/python3/dist-packages (from tabula-py) (1.7.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.3->tabula-py) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.3->tabula-py) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.3->tabula-py) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=0.25.3->tabula-py) (1.16.0)

# %%
from bs4 import BeautifulSoup
import requests
import json
import numpy as np
import gc
import pandas as pd
import tabula

# %%
df = tabula.io.read_pdf(r"/content/drive/MyDrive/2024 BIP DIP & AGSIP/Web Scraping/pre-owned-cars-for-sale_6142024.pdf", pages='all', pandas_options={"header": None})

# %%
for d in df:
  d.columns = ["#", "YEAR MODEL", "MAKE/MODEL", "PLATE NO.", "COLOR", "MILEAGE (KMS)", "REGISTERED IN", "SELLING PRICE", "FLOOR PRICE"]

# Concatenate Dataframes
psbank_df = pd.concat([d for d in df])
psbank_df.reset_index(drop=True, inplace=True)

# Reset Index
psbank_df.index.name = "ID"
psbank_df.index = np.arange(0, len(psbank_df))

# Remove headers
psbank_df.drop(0, inplace=True)
psbank_df.drop("#", axis=1, inplace=True)
psbank_df.drop(8, inplace=True)

# Remove duplicate rows and null-valued rows
psbank_df.drop_duplicates(inplace=True)
psbank_df.dropna(how="any", inplace=True)

# Reset Index
psbank_df.index = np.arange(0, len(psbank_df))


# Make Transmission Column
transmission = []

for s in psbank_df["MAKE/MODEL"]:
  psbank_df.replace(s, s.replace("\r", ""), inplace=True)

for s in psbank_df["MAKE/MODEL"]:
  make = s.split("-")
  transmission.append("AUTOMATIC" if "A" in make[-1] else ("MANUAL" if "M" in make[-1] else ""))

  psbank_df.replace(s, s.replace(f"-{make[-1]}", ""), inplace=True)

# Clean Info
for s in psbank_df["COLOR"]:
  psbank_df.replace(s, s.replace("\r", " "), inplace=True)

psbank_df.insert(3, "TRANSMISSION", transmission, True)


psbank_df
# Out:
#     YEAR MODEL                         MAKE/MODEL PLATE NO. TRANSMISSION  \
# 0         2023   HONDA HRV 1.5S CVT HONDA SENSING   E4-E093    AUTOMATIC
# 1         2021   NISSAN NAVARA 2.5 VE CALIBRE 4X2  NEV-7786    AUTOMATIC
# 2         2022  NISSAN URVAN NV350 2.5 18STR CRDI  CBD-6478       MANUAL
# 3         2019           TOYOTA FORTUNER 2.4G 4X2  CAS-9816    AUTOMATIC
# 4         2022           TOYOTA FORTUNER 2.4G 4X2  NIE-1544    AUTOMATIC
# ..         ...                                ...       ...          ...
# 98        2023                TOYOTA VIOS 1.3 XLE  GAP-5099    AUTOMATIC
# 99        2023                TOYOTA VIOS 1.3 XLE   Z4-Z820    AUTOMATIC
# 100       2023                TOYOTA VIOS 1.3 XLE   Z6-D047    AUTOMATIC
# 101       2024                TOYOTA VIOS 1.3 XLE   Z7-L191    AUTOMATIC
# 102       2024                TOYOTA VIOS 1.3 XLE   Z7-U717    AUTOMATIC
#
#                  COLOR MILEAGE (KMS)   REGISTERED IN SELLING PRICE  \
# 0       PLATINUM WHITE        12,169  GENERAL SANTOS  1,210,000.00
# 1         ALPINE WHITE        29,444      MUNTINLUPA  1,080,000.00
# 2      BRILIANT SILVER        15,033        REGION 3  1,050,000.00
# 3       ATITTUDE BLACK        54,033        REGION 3  1,150,000.00
# 4       SUPER WHITE II        67,538         BALANGA  1,560,000.00
# ..                 ...           ...             ...           ...
# 98         ALUM JADE M        14,580           RONDA    670,000.00
# 99   BLACKISH RED MICA         3,932            CEBU    650,000.00
# 100       ALUMINA JADE        11,152  CAGAYAN DE ORO    599,000.00
# 101    GRAYISH BLUE MI         4,774         TALISAY    694,000.00
# 102         SLVR MET 1         7,117            CEBU    779,000.00
#
#       FLOOR PRICE
# 0    1,089,000.00
# 1      972,000.00
# 2      945,000.00
# 3    1,035,000.00
# 4    1,404,000.00
# ..            ...
# 98     603,000.00
# 99     585,000.00
# 100    542,000.00
# 101    627,000.00
# 102    703,000.00
#
# [103 rows x 9 columns]

# %%
psbank_df.shape
# Out:
# (103, 9)

# %% [markdown]
# ### Convert and Export

# %% [markdown]
# Convert dataframe to parquet file.

# %%
psbank_df["YEAR MODEL"] = psbank_df["YEAR MODEL"].astype(int)
psbank_df.to_parquet(r"/content/drive/MyDrive/2024 BIP DIP & AGSIP/Web Scraping/JD_psbank_df.parquet")

# %% [markdown]
# # Automart.ph

# %%
url = r"https://api.automart.ph/products?page=1&limit=24"
content_html = requests.get(url)
content = content_html.json()
content['items']
# Out:
# [{'id': 55071,
#   'title': '2018 Lexus RX350 Sport  3.5',
#   'slug': 'a4u697',
#   'buy_now_price': 3195000,
#   'price': None,
#   'price_order': 3195000,
#   'is_featured': 0,
#   'view': 2047,
#   'winner_id': None,
#   'is_acuv': 0,
#   'is_repoz': 0,
#   'expired_at': '2024-06-28 06:20:00',
#   'car': {'odometer_reading': 77000,
#    'year_model': '2018',
#    'model': {'name': 'RX350',
#     'transmission_type': 'AT',
#     'fuel_type': 'Gas',
#     'vehicle_type': {'id': 3},
#     'make': {'name': 'Lexus'}}},
#   'acuv_certification': None,
#   'warehouse': {'location': 'Baesa',
#    'has_financing': 1,
#    'city': {'city_name': 'Quezon City'},
#    'bank': {'id': 1,
#     'min_loan_amount': 260000,
#     'year_minus_count': 4,
#     'has_processing_fee': 0}},
#   'media_images': [{'id': 373967,
#     'user_id': 1,
#     'ad_id': 55071,
#     'post_id': None,
#     'media_name': 'used-Lexus-RX350-a4u697-373967.webp',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/a4u697/used-Lexus-RX350-a4u697-373967.webp',
#     'type': 'image',
#     'is_feature': '',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/a4u697/used-Lexus-RX350-a4u697-373967.png'},
#    {'id': 373968,
#     'user_id': 1,
#     'ad_id': 55071,
#     'post_id': None,
#     'media_name': 'used-Lexus-RX350-a4u697-373968.webp',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/a4u697/used-Lexus-RX350-a4u697-373968.webp',
#     'type': 'image',
#     'is_feature': '1',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/a4u697/used-Lexus-RX350-a4u697-373968.png'},
#    {'id': 373969,
#     'user_id': 1,
#     'ad_id': 55071,
#     'post_id': None,
#     'media_name': 'used-Lexus-RX350-a4u697-373969.webp',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/a4u697/used-Lexus-RX350-a4u697-373969.webp',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/a4u697/used-Lexus-RX350-a4u697-373969.png'},
#    {'id': 373970,
#     'user_id': 1,
#     'ad_id': 55071,
#     'post_id': None,
#     'media_name': 'used-Lexus-RX350-a4u697-373970.webp',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/a4u697/used-Lexus-RX350-a4u697-373970.webp',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/a4u697/used-Lexus-RX350-a4u697-373970.png'},
#    {'id': 373971,
#     'user_id': 1,
#     'ad_id': 55071,
#     'post_id': None,
#     'media_name': 'used-Lexus-RX350-a4u697-373971.webp',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/a4u697/used-Lexus-RX350-a4u697-373971.webp',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/a4u697/used-Lexus-RX350-a4u697-373971.png'}],
#   'first_media_image': {'id': 373967,
#    'user_id': 1,
#    'ad_id': 55071,
#    'post_id': None,
#    'media_name': 'used-Lexus-RX350-a4u697-373967.webp',
#    'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/a4u697/used-Lexus-RX350-a4u697-373967.webp',
#    'type': 'image',
#    'is_feature': '',
#    'storage': 'do_spaces',
#    'ref': 'ad',
#    'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/a4u697/used-Lexus-RX350-a4u697-373967.png'},
#   'featured_media_image': {'id': 373968,
#    'user_id': 1,
#    'ad_id': 55071,
#    'post_id': None,
#    'media_name': 'used-Lexus-RX350-a4u697-373968.webp',
#    'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/a4u697/used-Lexus-RX350-a4u697-373968.webp',
#    'type': 'image',
#    'is_feature': '1',
#    'storage': 'do_spaces',
#    'ref': 'ad',
#    'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/a4u697/used-Lexus-RX350-a4u697-373968.png'},
#   'top_bid': None,
#   'installment_terms': {'status': False,
#    'message': 'year model 2018 and below is not available for financing'}},
#  {'id': 55096,
#   'title': '2020 Volvo X40 T5 2.0',
#   'slug': 'ngj8987',
#   'buy_now_price': 2343000,
#   'price': None,
#   'price_order': 2343000,
#   'is_featured': 0,
#   'view': 1147,
#   'winner_id': None,
#   'is_acuv': 0,
#   'is_repoz': 0,
#   'expired_at': '2024-06-28 06:20:00',
#   'car': {'odometer_reading': 9000,
#    'year_model': '2020',
#    'model': {'name': 'X40',
#     'transmission_type': 'AT',
#     'fuel_type': 'Gas',
#     'vehicle_type': {'id': 4},
#     'make': {'name': 'Volvo'}}},
#   'acuv_certification': None,
#   'warehouse': {'location': 'Baesa',
#    'has_financing': 1,
#    'city': {'city_name': 'Quezon City'},
#    'bank': {'id': 1,
#     'min_loan_amount': 260000,
#     'year_minus_count': 4,
#     'has_processing_fee': 0}},
#   'media_images': [{'id': 373989,
#     'user_id': 1,
#     'ad_id': 55096,
#     'post_id': None,
#     'media_name': 'used-Volvo-X40-ngj8987-373989.webp',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/ngj8987/used-Volvo-X40-ngj8987-373989.webp',
#     'type': 'image',
#     'is_feature': '',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/ngj8987/used-Volvo-X40-ngj8987-373989.png'},
#    {'id': 373990,
#     'user_id': 1,
#     'ad_id': 55096,
#     'post_id': None,
#     'media_name': 'used-Volvo-X40-ngj8987-373990.webp',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/ngj8987/used-Volvo-X40-ngj8987-373990.webp',
#     'type': 'image',
#     'is_feature': '1',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/ngj8987/used-Volvo-X40-ngj8987-373990.png'},
#    {'id': 373991,
#     'user_id': 1,
#     'ad_id': 55096,
#     'post_id': None,
#     'media_name': 'used-Volvo-X40-ngj8987-373991.webp',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/ngj8987/used-Volvo-X40-ngj8987-373991.webp',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/ngj8987/used-Volvo-X40-ngj8987-373991.png'},
#    {'id': 373992,
#     'user_id': 1,
#     'ad_id': 55096,
#     'post_id': None,
#     'media_name': 'used-Volvo-X40-ngj8987-373992.webp',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/ngj8987/used-Volvo-X40-ngj8987-373992.webp',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/ngj8987/used-Volvo-X40-ngj8987-373992.png'}],
#   'first_media_image': {'id': 373989,
#    'user_id': 1,
#    'ad_id': 55096,
#    'post_id': None,
#    'media_name': 'used-Volvo-X40-ngj8987-373989.webp',
#    'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/ngj8987/used-Volvo-X40-ngj8987-373989.webp',
#    'type': 'image',
#    'is_feature': '',
#    'storage': 'do_spaces',
#    'ref': 'ad',
#    'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/ngj8987/used-Volvo-X40-ngj8987-373989.png'},
#   'featured_media_image': {'id': 373990,
#    'user_id': 1,
#    'ad_id': 55096,
#    'post_id': None,
#    'media_name': 'used-Volvo-X40-ngj8987-373990.webp',
#    'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/ngj8987/used-Volvo-X40-ngj8987-373990.webp',
#    'type': 'image',
#    'is_feature': '1',
#    'storage': 'do_spaces',
#    'ref': 'ad',
#    'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/ngj8987/used-Volvo-X40-ngj8987-373990.png'},
#   'top_bid': None,
#   'installment_terms': {'status': False,
#    'message': 'year model 2020 and below is not available for financing'}},
#  {'id': 58213,
#   'title': '2016 Ford Mustang V6 Coupe ',
#   'slug': 'acv8080',
#   'buy_now_price': 2292780,
#   'price': '2226000.00',
#   'price_order': 2226000,
#   'is_featured': 0,
#   'view': 740,
#   'winner_id': None,
#   'is_acuv': 1,
#   'is_repoz': 0,
#   'expired_at': '2024-06-27 11:00:00',
#   'car': {'odometer_reading': 23509,
#    'year_model': '2016',
#    'model': {'name': 'Mustang',
#     'transmission_type': 'AT',
#     'fuel_type': 'Gas',
#     'vehicle_type': {'id': 3},
#     'make': {'name': 'Ford'}}},
#   'acuv_certification': {'general_name': 'Bronze'},
#   'warehouse': {'location': 'Dacudao Avenue',
#    'has_financing': 1,
#    'city': {'city_name': 'Davao'},
#    'bank': {'id': 16,
#     'min_loan_amount': 250000,
#     'year_minus_count': 60,
#     'has_processing_fee': 1}},
#   'media_images': [{'id': 380302,
#     'user_id': 1,
#     'ad_id': 58213,
#     'post_id': None,
#     'media_name': 'used-Ford-Mustang-acv8080-380292.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv8080/used-Ford-Mustang-acv8080-380292.jpg',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv8080/used-Ford-Mustang-acv8080-380292.png'},
#    {'id': 380303,
#     'user_id': 1,
#     'ad_id': 58213,
#     'post_id': None,
#     'media_name': 'used-Ford-Mustang-acv8080-380303.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv8080/used-Ford-Mustang-acv8080-380303.jpg',
#     'type': 'image',
#     'is_feature': '1',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv8080/used-Ford-Mustang-acv8080-380303.png'},
#    {'id': 380304,
#     'user_id': 1,
#     'ad_id': 58213,
#     'post_id': None,
#     'media_name': 'used-Ford-Mustang-acv8080-380304.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv8080/used-Ford-Mustang-acv8080-380304.jpg',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv8080/used-Ford-Mustang-acv8080-380304.png'},
#    {'id': 380305,
#     'user_id': 1,
#     'ad_id': 58213,
#     'post_id': None,
#     'media_name': 'used-Ford-Mustang-acv8080-380305.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv8080/used-Ford-Mustang-acv8080-380305.jpg',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv8080/used-Ford-Mustang-acv8080-380305.png'},
#    {'id': 380306,
#     'user_id': 1,
#     'ad_id': 58213,
#     'post_id': None,
#     'media_name': 'used-Ford-Mustang-acv8080-380306.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv8080/used-Ford-Mustang-acv8080-380306.jpg',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv8080/used-Ford-Mustang-acv8080-380306.png'},
#    {'id': 380307,
#     'user_id': 1,
#     'ad_id': 58213,
#     'post_id': None,
#     'media_name': 'used-Ford-Mustang-acv8080-380307.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv8080/used-Ford-Mustang-acv8080-380307.jpg',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv8080/used-Ford-Mustang-acv8080-380307.png'},
#    {'id': 380308,
#     'user_id': 1,
#     'ad_id': 58213,
#     'post_id': None,
#     'media_name': 'used-Ford-Mustang-acv8080-380308.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv8080/used-Ford-Mustang-acv8080-380308.jpg',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv8080/used-Ford-Mustang-acv8080-380308.png'},
#    {'id': 380309,
#     'user_id': 1,
#     'ad_id': 58213,
#     'post_id': None,
#     'media_name': 'used-Ford-Mustang-acv8080-380309.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv8080/used-Ford-Mustang-acv8080-380309.jpg',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv8080/used-Ford-Mustang-acv8080-380309.png'},
#    {'id': 380310,
#     'user_id': 1,
#     'ad_id': 58213,
#     'post_id': None,
#     'media_name': 'used-Ford-Mustang-acv8080-380310.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv8080/used-Ford-Mustang-acv8080-380310.jpg',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv8080/used-Ford-Mustang-acv8080-380310.png'},
#    {'id': 380311,
#     'user_id': 1,
#     'ad_id': 58213,
#     'post_id': None,
#     'media_name': 'used-Ford-Mustang-acv8080-380311.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv8080/used-Ford-Mustang-acv8080-380311.jpg',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv8080/used-Ford-Mustang-acv8080-380311.png'},
#    {'id': 380312,
#     'user_id': 1,
#     'ad_id': 58213,
#     'post_id': None,
#     'media_name': 'used-Ford-Mustang-acv8080-380312.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv8080/used-Ford-Mustang-acv8080-380312.jpg',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv8080/used-Ford-Mustang-acv8080-380312.png'},
#    {'id': 380313,
#     'user_id': 1,
#     'ad_id': 58213,
#     'post_id': None,
#     'media_name': 'used-Ford-Mustang-acv8080-380313.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv8080/used-Ford-Mustang-acv8080-380313.jpg',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv8080/used-Ford-Mustang-acv8080-380313.png'},
#    {'id': 380314,
#     'user_id': 1,
#     'ad_id': 58213,
#     'post_id': None,
#     'media_name': 'used-Ford-Mustang-acv8080-380314.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv8080/used-Ford-Mustang-acv8080-380314.jpg',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv8080/used-Ford-Mustang-acv8080-380314.png'},
#    {'id': 380315,
#     'user_id': 1,
#     'ad_id': 58213,
#     'post_id': None,
#     'media_name': 'used-Ford-Mustang-acv8080-380315.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv8080/used-Ford-Mustang-acv8080-380315.jpg',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv8080/used-Ford-Mustang-acv8080-380315.png'}],
#   'first_media_image': {'id': 380302,
#    'user_id': 1,
#    'ad_id': 58213,
#    'post_id': None,
#    'media_name': 'used-Ford-Mustang-acv8080-380292.jpg',
#    'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv8080/used-Ford-Mustang-acv8080-380292.jpg',
#    'type': 'image',
#    'is_feature': '0',
#    'storage': 'do_spaces',
#    'ref': 'ad',
#    'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv8080/used-Ford-Mustang-acv8080-380292.png'},
#   'featured_media_image': {'id': 380303,
#    'user_id': 1,
#    'ad_id': 58213,
#    'post_id': None,
#    'media_name': 'used-Ford-Mustang-acv8080-380303.jpg',
#    'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv8080/used-Ford-Mustang-acv8080-380303.jpg',
#    'type': 'image',
#    'is_feature': '1',
#    'storage': 'do_spaces',
#    'ref': 'ad',
#    'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv8080/used-Ford-Mustang-acv8080-380303.png'},
#   'top_bid': None,
#   'installment_terms': {'status': True,
#    'message': 'financing available',
#    'data': {'buy_terms': [{'rate_name': '20',
#       'rate_data': [{'label': '4 years',
#         'is_default': 1,
#         'duration': 48,
#         'interest_rate': 1.45,
#         'monthly_amortization': 64962},
#        {'label': '3 years',
#         'is_default': 0,
#         'duration': 36,
#         'interest_rate': 1.3,
#         'monthly_amortization': 74897},
#        {'label': '2 years',
#         'is_default': 0,
#         'duration': 24,
#         'interest_rate': 1.29,
#         'monthly_amortization': 100118},
#        {'label': '1 year',
#         'is_default': 0,
#         'duration': 12,
#         'interest_rate': 1.3,
#         'monthly_amortization': 177308}],
#       'loan_amount': 1834224,
#       'downpayment': 458556,
#       'processing_fee': 128396,
#       'other_charges': 0},
#      {'rate_name': '30',
#       'rate_data': [{'label': '4 years',
#         'is_default': 1,
#         'duration': 48,
#         'interest_rate': 1.45,
#         'monthly_amortization': 56842},
#        {'label': '3 years',
#         'is_default': 0,
#         'duration': 36,
#         'interest_rate': 1.3,
#         'monthly_amortization': 65535},
#        {'label': '2 years',
#         'is_default': 0,
#         'duration': 24,
#         'interest_rate': 1.29,
#         'monthly_amortization': 87603},
#        {'label': '1 year',
#         'is_default': 0,
#         'duration': 12,
#         'interest_rate': 1.3,
#         'monthly_amortization': 155145}],
#       'loan_amount': 1604946,
#       'downpayment': 687834,
#       'processing_fee': 112346,
#       'other_charges': 0},
#      {'rate_name': '40',
#       'rate_data': [{'label': '4 years',
#         'is_default': 1,
#         'duration': 48,
#         'interest_rate': 1.45,
#         'monthly_amortization': 48722},
#        {'label': '3 years',
#         'is_default': 0,
#         'duration': 36,
#         'interest_rate': 1.3,
#         'monthly_amortization': 56173},
#        {'label': '2 years',
#         'is_default': 0,
#         'duration': 24,
#         'interest_rate': 1.29,
#         'monthly_amortization': 75089},
#        {'label': '1 year',
#         'is_default': 0,
#         'duration': 12,
#         'interest_rate': 1.3,
#         'monthly_amortization': 132981}],
#       'loan_amount': 1375668,
#       'downpayment': 917112,
#       'processing_fee': 96297,
#       'other_charges': 0},
#      {'rate_name': '50',
#       'rate_data': [{'label': '4 years',
#         'is_default': 1,
#         'duration': 48,
#         'interest_rate': 1.45,
#         'monthly_amortization': 40601},
#        {'label': '3 years',
#         'is_default': 0,
#         'duration': 36,
#         'interest_rate': 1.3,
#         'monthly_amortization': 46811},
#        {'label': '2 years',
#         'is_default': 0,
#         'duration': 24,
#         'interest_rate': 1.29,
#         'monthly_amortization': 62574},
#        {'label': '1 year',
#         'is_default': 0,
#         'duration': 12,
#         'interest_rate': 1.3,
#         'monthly_amortization': 110818}],
#       'loan_amount': 1146390,
#       'downpayment': 1146390,
#       'processing_fee': 80247,
#       'other_charges': 0}],
#     'bid_terms': [{'rate_name': '20',
#       'rate_data': [{'label': '4 years',
#         'is_default': 1,
#         'duration': 48,
#         'interest_rate': 1.45,
#         'monthly_amortization': 63070},
#        {'label': '3 years',
#         'is_default': 0,
#         'duration': 36,
#         'interest_rate': 1.3,
#         'monthly_amortization': 72716},
#        {'label': '2 years',
#         'is_default': 0,
#         'duration': 24,
#         'interest_rate': 1.29,
#         'monthly_amortization': 97202},
#        {'label': '1 year',
#         'is_default': 0,
#         'duration': 12,
#         'interest_rate': 1.3,
#         'monthly_amortization': 172144}],
#       'loan_amount': 1780800,
#       'downpayment': 445200,
#       'processing_fee': 124656,
#       'other_charges': 0},
#      {'rate_name': '30',
#       'rate_data': [{'label': '4 years',
#         'is_default': 1,
#         'duration': 48,
#         'interest_rate': 1.45,
#         'monthly_amortization': 55186},
#        {'label': '3 years',
#         'is_default': 0,
#         'duration': 36,
#         'interest_rate': 1.3,
#         'monthly_amortization': 63627},
#        {'label': '2 years',
#         'is_default': 0,
#         'duration': 24,
#         'interest_rate': 1.29,
#         'monthly_amortization': 85052},
#        {'label': '1 year',
#         'is_default': 0,
#         'duration': 12,
#         'interest_rate': 1.3,
#         'monthly_amortization': 150626}],
#       'loan_amount': 1558200,
#       'downpayment': 667800,
#       'processing_fee': 109074,
#       'other_charges': 0},
#      {'rate_name': '40',
#       'rate_data': [{'label': '4 years',
#         'is_default': 1,
#         'duration': 48,
#         'interest_rate': 1.45,
#         'monthly_amortization': 47303},
#        {'label': '3 years',
#         'is_default': 0,
#         'duration': 36,
#         'interest_rate': 1.3,
#         'monthly_amortization': 54537},
#        {'label': '2 years',
#         'is_default': 0,
#         'duration': 24,
#         'interest_rate': 1.29,
#         'monthly_amortization': 72902},
#        {'label': '1 year',
#         'is_default': 0,
#         'duration': 12,
#         'interest_rate': 1.3,
#         'monthly_amortization': 129108}],
#       'loan_amount': 1335600,
#       'downpayment': 890400,
#       'processing_fee': 93492,
#       'other_charges': 0},
#      {'rate_name': '50',
#       'rate_data': [{'label': '4 years',
#         'is_default': 1,
#         'duration': 48,
#         'interest_rate': 1.45,
#         'monthly_amortization': 39419},
#        {'label': '3 years',
#         'is_default': 0,
#         'duration': 36,
#         'interest_rate': 1.3,
#         'monthly_amortization': 45448},
#        {'label': '2 years',
#         'is_default': 0,
#         'duration': 24,
#         'interest_rate': 1.29,
#         'monthly_amortization': 60751},
#        {'label': '1 year',
#         'is_default': 0,
#         'duration': 12,
#         'interest_rate': 1.3,
#         'monthly_amortization': 107590}],
#       'loan_amount': 1113000,
#       'downpayment': 1113000,
#       'processing_fee': 77910,
#       'other_charges': 0}]}}},
#  {'id': 55074,
#   'title': '2016 Mercedes Benz C250 Coupe ',
#   'slug': 'gs2400',
#   'buy_now_price': 2024000,
#   'price': None,
#   'price_order': 2024000,
#   'is_featured': 0,
#   'view': 1455,
#   'winner_id': None,
#   'is_acuv': 0,
#   'is_repoz': 0,
#   'expired_at': '2024-06-28 06:20:00',
#   'car': {'odometer_reading': 43000,
#    'year_model': '2016',
#    'model': {'name': 'C250',
#     'transmission_type': 'AT',
#     'fuel_type': 'Gas',
#     'vehicle_type': {'id': 3},
#     'make': {'name': 'Mercedes Benz'}}},
#   'acuv_certification': None,
#   'warehouse': {'location': 'Baesa',
#    'has_financing': 1,
#    'city': {'city_name': 'Quezon City'},
#    'bank': {'id': 1,
#     'min_loan_amount': 260000,
#     'year_minus_count': 4,
#     'has_processing_fee': 0}},
#   'media_images': [{'id': 373982,
#     'user_id': 1,
#     'ad_id': 55074,
#     'post_id': None,
#     'media_name': 'used-Mercedes Benz-C250-gs2400-373982.webp',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/gs2400/used-Mercedes Benz-C250-gs2400-373982.webp',
#     'type': 'image',
#     'is_feature': '',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/gs2400/used-Mercedes Benz-C250-gs2400-373982.png'},
#    {'id': 373983,
#     'user_id': 1,
#     'ad_id': 55074,
#     'post_id': None,
#     'media_name': 'used-Mercedes Benz-C250-gs2400-373983.webp',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/gs2400/used-Mercedes Benz-C250-gs2400-373983.webp',
#     'type': 'image',
#     'is_feature': '1',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/gs2400/used-Mercedes Benz-C250-gs2400-373983.png'},
#    {'id': 373984,
#     'user_id': 1,
#     'ad_id': 55074,
#     'post_id': None,
#     'media_name': 'used-Mercedes Benz-C250-gs2400-373984.webp',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/gs2400/used-Mercedes Benz-C250-gs2400-373984.webp',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/gs2400/used-Mercedes Benz-C250-gs2400-373984.png'}],
#   'first_media_image': {'id': 373982,
#    'user_id': 1,
#    'ad_id': 55074,
#    'post_id': None,
#    'media_name': 'used-Mercedes Benz-C250-gs2400-373982.webp',
#    'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/gs2400/used-Mercedes Benz-C250-gs2400-373982.webp',
#    'type': 'image',
#    'is_feature': '',
#    'storage': 'do_spaces',
#    'ref': 'ad',
#    'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/gs2400/used-Mercedes Benz-C250-gs2400-373982.png'},
#   'featured_media_image': {'id': 373983,
#    'user_id': 1,
#    'ad_id': 55074,
#    'post_id': None,
#    'media_name': 'used-Mercedes Benz-C250-gs2400-373983.webp',
#    'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/gs2400/used-Mercedes Benz-C250-gs2400-373983.webp',
#    'type': 'image',
#    'is_feature': '1',
#    'storage': 'do_spaces',
#    'ref': 'ad',
#    'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/gs2400/used-Mercedes Benz-C250-gs2400-373983.png'},
#   'top_bid': None,
#   'installment_terms': {'status': False,
#    'message': 'year model 2016 and below is not available for financing'}},
#  {'id': 50261,
#   'title': '2011 Mercedes Benz S350 3.5',
#   'slug': 'pas924',
#   'buy_now_price': 1836450,
#   'price': None,
#   'price_order': 1836450,
#   'is_featured': 0,
#   'view': 2788,
#   'winner_id': None,
#   'is_acuv': 0,
#   'is_repoz': 0,
#   'expired_at': '2024-06-28 02:50:00',
#   'car': {'odometer_reading': 27000,
#    'year_model': '2011',
#    'model': {'name': 'Benz',
#     'transmission_type': 'AT',
#     'fuel_type': 'Gas',
#     'vehicle_type': {'id': 5},
#     'make': {'name': 'Mercedes'}}},
#   'acuv_certification': None,
#   'warehouse': {'location': 'Kalayaan Ave',
#    'has_financing': 1,
#    'city': {'city_name': 'Quezon City'},
#    'bank': {'id': 7,
#     'min_loan_amount': 250000,
#     'year_minus_count': 60,
#     'has_processing_fee': 1}},
#   'media_images': [{'id': 345335,
#     'user_id': 1,
#     'ad_id': 50261,
#     'post_id': None,
#     'media_name': 'used-Mercedez-Benz-pas924-345335.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/pas924/used-Mercedez-Benz-pas924-345335.jpg',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/pas924/used-Mercedez-Benz-pas924-345335.png'},
#    {'id': 345336,
#     'user_id': 1,
#     'ad_id': 50261,
#     'post_id': None,
#     'media_name': 'used-Mercedez-Benz-pas924-345336.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/pas924/used-Mercedez-Benz-pas924-345336.jpg',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/pas924/used-Mercedez-Benz-pas924-345336.png'},
#    {'id': 345337,
#     'user_id': 1,
#     'ad_id': 50261,
#     'post_id': None,
#     'media_name': 'used-Mercedez-Benz-pas924-345337.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/pas924/used-Mercedez-Benz-pas924-345337.jpg',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/pas924/used-Mercedez-Benz-pas924-345337.png'},
#    {'id': 345338,
#     'user_id': 1,
#     'ad_id': 50261,
#     'post_id': None,
#     'media_name': 'used-Mercedez-Benz-pas924-345338.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/pas924/used-Mercedez-Benz-pas924-345338.jpg',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/pas924/used-Mercedez-Benz-pas924-345338.png'},
#    {'id': 345339,
#     'user_id': 1,
#     'ad_id': 50261,
#     'post_id': None,
#     'media_name': 'used-Mercedez-Benz-pas924-345339.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/pas924/used-Mercedez-Benz-pas924-345339.jpg',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/pas924/used-Mercedez-Benz-pas924-345339.png'},
#    {'id': 345340,
#     'user_id': 1,
#     'ad_id': 50261,
#     'post_id': None,
#     'media_name': 'used-Mercedez-Benz-pas924-345340.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/pas924/used-Mercedez-Benz-pas924-345340.jpg',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/pas924/used-Mercedez-Benz-pas924-345340.png'},
#    {'id': 345341,
#     'user_id': 1,
#     'ad_id': 50261,
#     'post_id': None,
#     'media_name': 'used-Mercedez-Benz-pas924-345341.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/pas924/used-Mercedez-Benz-pas924-345341.jpg',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/pas924/used-Mercedez-Benz-pas924-345341.png'},
#    {'id': 345342,
#     'user_id': 1,
#     'ad_id': 50261,
#     'post_id': None,
#     'media_name': 'used-Mercedez-Benz-pas924-345342.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/pas924/used-Mercedez-Benz-pas924-345342.jpg',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/pas924/used-Mercedez-Benz-pas924-345342.png'},
#    {'id': 345343,
#     'user_id': 1,
#     'ad_id': 50261,
#     'post_id': None,
#     'media_name': 'used-Mercedez-Benz-pas924-345343.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/pas924/used-Mercedez-Benz-pas924-345343.jpg',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/pas924/used-Mercedez-Benz-pas924-345343.png'},
#    {'id': 345344,
#     'user_id': 1,
#     'ad_id': 50261,
#     'post_id': None,
#     'media_name': 'used-Mercedez-Benz-pas924-345344.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/pas924/used-Mercedez-Benz-pas924-345344.jpg',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/pas924/used-Mercedez-Benz-pas924-345344.png'},
#    {'id': 345345,
#     'user_id': 1,
#     'ad_id': 50261,
#     'post_id': None,
#     'media_name': 'used-Mercedez-Benz-pas924-345345.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/pas924/used-Mercedez-Benz-pas924-345345.jpg',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/pas924/used-Mercedez-Benz-pas924-345345.png'},
#    {'id': 345346,
#     'user_id': 1,
#     'ad_id': 50261,
#     'post_id': None,
#     'media_name': 'used-Mercedes-Benz-pas924-345346.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/pas924/used-Mercedes-Benz-pas924-345346.jpg',
#     'type': 'image',
#     'is_feature': '1',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/pas924/used-Mercedes-Benz-pas924-345346.png'},
#    {'id': 349272,
#     'user_id': 1,
#     'ad_id': 50261,
#     'post_id': None,
#     'media_name': 'used-Mercedes-Benz-pas924-349272.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/pas924/used-Mercedes-Benz-pas924-349272.jpg',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/pas924/used-Mercedes-Benz-pas924-349272.png'}],
#   'first_media_image': {'id': 345335,
#    'user_id': 1,
#    'ad_id': 50261,
#    'post_id': None,
#    'media_name': 'used-Mercedez-Benz-pas924-345335.jpg',
#    'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/pas924/used-Mercedez-Benz-pas924-345335.jpg',
#    'type': 'image',
#    'is_feature': '0',
#    'storage': 'do_spaces',
#    'ref': 'ad',
#    'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/pas924/used-Mercedez-Benz-pas924-345335.png'},
#   'featured_media_image': {'id': 345346,
#    'user_id': 1,
#    'ad_id': 50261,
#    'post_id': None,
#    'media_name': 'used-Mercedes-Benz-pas924-345346.jpg',
#    'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/pas924/used-Mercedes-Benz-pas924-345346.jpg',
#    'type': 'image',
#    'is_feature': '1',
#    'storage': 'do_spaces',
#    'ref': 'ad',
#    'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/pas924/used-Mercedes-Benz-pas924-345346.png'},
#   'top_bid': None,
#   'installment_terms': {'status': True,
#    'message': 'financing available',
#    'data': {'buy_terms': [{'rate_name': '20',
#       'rate_data': [{'label': '4 years',
#         'is_default': 1,
#         'duration': 48,
#         'interest_rate': 1.45,
#         'monthly_amortization': 51910},
#        {'label': '3 years',
#         'is_default': 0,
#         'duration': 36,
#         'interest_rate': 1.45,
#         'monthly_amortization': 62113},
#        {'label': '2 years',
#         'is_default': 0,
#         'duration': 24,
#         'interest_rate': 1.5,
#         'monthly_amortization': 83252},
#        {'label': '1 year',
#         'is_default': 0,
#         'duration': 12,
#         'interest_rate': 1.5,
#         'monthly_amortization': 144467}],
#       'loan_amount': 1469160,
#       'downpayment': 367290,
#       'processing_fee': 102841,
#       'other_charges': 0},
#      {'rate_name': '30',
#       'rate_data': [{'label': '4 years',
#         'is_default': 1,
#         'duration': 48,
#         'interest_rate': 1.45,
#         'monthly_amortization': 45422},
#        {'label': '3 years',
#         'is_default': 0,
#         'duration': 36,
#         'interest_rate': 1.45,
#         'monthly_amortization': 54349},
#        {'label': '2 years',
#         'is_default': 0,
#         'duration': 24,
#         'interest_rate': 1.5,
#         'monthly_amortization': 72846},
#        {'label': '1 year',
#         'is_default': 0,
#         'duration': 12,
#         'interest_rate': 1.5,
#         'monthly_amortization': 126409}],
#       'loan_amount': 1285515,
#       'downpayment': 550935,
#       'processing_fee': 89986,
#       'other_charges': 0},
#      {'rate_name': '40',
#       'rate_data': [{'label': '4 years',
#         'is_default': 1,
#         'duration': 48,
#         'interest_rate': 1.45,
#         'monthly_amortization': 38933},
#        {'label': '3 years',
#         'is_default': 0,
#         'duration': 36,
#         'interest_rate': 1.45,
#         'monthly_amortization': 46585},
#        {'label': '2 years',
#         'is_default': 0,
#         'duration': 24,
#         'interest_rate': 1.5,
#         'monthly_amortization': 62439},
#        {'label': '1 year',
#         'is_default': 0,
#         'duration': 12,
#         'interest_rate': 1.5,
#         'monthly_amortization': 108351}],
#       'loan_amount': 1101870,
#       'downpayment': 734580,
#       'processing_fee': 77131,
#       'other_charges': 0},
#      {'rate_name': '50',
#       'rate_data': [{'label': '4 years',
#         'is_default': 1,
#         'duration': 48,
#         'interest_rate': 1.45,
#         'monthly_amortization': 32444},
#        {'label': '3 years',
#         'is_default': 0,
#         'duration': 36,
#         'interest_rate': 1.45,
#         'monthly_amortization': 38821},
#        {'label': '2 years',
#         'is_default': 0,
#         'duration': 24,
#         'interest_rate': 1.5,
#         'monthly_amortization': 52033},
#        {'label': '1 year',
#         'is_default': 0,
#         'duration': 12,
#         'interest_rate': 1.5,
#         'monthly_amortization': 90292}],
#       'loan_amount': 918225,
#       'downpayment': 918225,
#       'processing_fee': 64276,
#       'other_charges': 0}],
#     'bid_terms': []}}},
#  {'id': 58083,
#   'title': '2019 Toyota Hi-Ace GL Grandia 2.8',
#   'slug': 'acv3809',
#   'buy_now_price': 1768716,
#   'price': '1717200.00',
#   'price_order': 1717200,
#   'is_featured': 0,
#   'view': 1415,
#   'winner_id': None,
#   'is_acuv': 1,
#   'is_repoz': 0,
#   'expired_at': '2024-06-27 11:00:00',
#   'car': {'odometer_reading': 33533,
#    'year_model': '2019',
#    'model': {'name': 'Hi-Ace',
#     'transmission_type': 'MT',
#     'fuel_type': 'Diesel',
#     'vehicle_type': {'id': 5},
#     'make': {'name': 'Toyota'}}},
#   'acuv_certification': {'general_name': 'Silver'},
#   'warehouse': {'location': 'Dacudao Avenue',
#    'has_financing': 1,
#    'city': {'city_name': 'Davao'},
#    'bank': {'id': 16,
#     'min_loan_amount': 250000,
#     'year_minus_count': 60,
#     'has_processing_fee': 1}},
#   'media_images': [{'id': 379776,
#     'user_id': 1,
#     'ad_id': 58083,
#     'post_id': None,
#     'media_name': 'used-Toyota-Hi-Ace-acv3809-379776.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv3809/used-Toyota-Hi-Ace-acv3809-379776.jpg',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv3809/used-Toyota-Hi-Ace-acv3809-379776.png'},
#    {'id': 379777,
#     'user_id': 1,
#     'ad_id': 58083,
#     'post_id': None,
#     'media_name': 'used-Toyota-Hi-Ace-acv3809-379777.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv3809/used-Toyota-Hi-Ace-acv3809-379777.jpg',
#     'type': 'image',
#     'is_feature': '1',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv3809/used-Toyota-Hi-Ace-acv3809-379777.png'},
#    {'id': 379778,
#     'user_id': 1,
#     'ad_id': 58083,
#     'post_id': None,
#     'media_name': 'used-Toyota-Hi-Ace-acv3809-379778.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv3809/used-Toyota-Hi-Ace-acv3809-379778.jpg',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv3809/used-Toyota-Hi-Ace-acv3809-379778.png'},
#    {'id': 379779,
#     'user_id': 1,
#     'ad_id': 58083,
#     'post_id': None,
#     'media_name': 'used-Toyota-Hi-Ace-acv3809-379779.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv3809/used-Toyota-Hi-Ace-acv3809-379779.jpg',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv3809/used-Toyota-Hi-Ace-acv3809-379779.png'},
#    {'id': 379780,
#     'user_id': 1,
#     'ad_id': 58083,
#     'post_id': None,
#     'media_name': 'used-Toyota-Hi-Ace-acv3809-379780.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv3809/used-Toyota-Hi-Ace-acv3809-379780.jpg',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv3809/used-Toyota-Hi-Ace-acv3809-379780.png'},
#    {'id': 379781,
#     'user_id': 1,
#     'ad_id': 58083,
#     'post_id': None,
#     'media_name': 'used-Toyota-Hi-Ace-acv3809-379781.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv3809/used-Toyota-Hi-Ace-acv3809-379781.jpg',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv3809/used-Toyota-Hi-Ace-acv3809-379781.png'},
#    {'id': 379782,
#     'user_id': 1,
#     'ad_id': 58083,
#     'post_id': None,
#     'media_name': 'used-Toyota-Hi-Ace-acv3809-379782.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv3809/used-Toyota-Hi-Ace-acv3809-379782.jpg',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv3809/used-Toyota-Hi-Ace-acv3809-379782.png'}],
#   'first_media_image': {'id': 379776,
#    'user_id': 1,
#    'ad_id': 58083,
#    'post_id': None,
#    'media_name': 'used-Toyota-Hi-Ace-acv3809-379776.jpg',
#    'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv3809/used-Toyota-Hi-Ace-acv3809-379776.jpg',
#    'type': 'image',
#    'is_feature': '0',
#    'storage': 'do_spaces',
#    'ref': 'ad',
#    'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv3809/used-Toyota-Hi-Ace-acv3809-379776.png'},
#   'featured_media_image': {'id': 379777,
#    'user_id': 1,
#    'ad_id': 58083,
#    'post_id': None,
#    'media_name': 'used-Toyota-Hi-Ace-acv3809-379777.jpg',
#    'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv3809/used-Toyota-Hi-Ace-acv3809-379777.jpg',
#    'type': 'image',
#    'is_feature': '1',
#    'storage': 'do_spaces',
#    'ref': 'ad',
#    'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/acv3809/used-Toyota-Hi-Ace-acv3809-379777.png'},
#   'top_bid': None,
#   'installment_terms': {'status': True,
#    'message': 'financing available',
#    'data': {'buy_terms': [{'rate_name': '20',
#       'rate_data': [{'label': '4 years',
#         'is_default': 1,
#         'duration': 48,
#         'interest_rate': 1.45,
#         'monthly_amortization': 50114},
#        {'label': '3 years',
#         'is_default': 0,
#         'duration': 36,
#         'interest_rate': 1.3,
#         'monthly_amortization': 57778},
#        {'label': '2 years',
#         'is_default': 0,
#         'duration': 24,
#         'interest_rate': 1.29,
#         'monthly_amortization': 77234},
#        {'label': '1 year',
#         'is_default': 0,
#         'duration': 12,
#         'interest_rate': 1.3,
#         'monthly_amortization': 136781}],
#       'loan_amount': 1414973,
#       'downpayment': 353743,
#       'processing_fee': 99048,
#       'other_charges': 0},
#      {'rate_name': '30',
#       'rate_data': [{'label': '4 years',
#         'is_default': 1,
#         'duration': 48,
#         'interest_rate': 1.45,
#         'monthly_amortization': 43849},
#        {'label': '3 years',
#         'is_default': 0,
#         'duration': 36,
#         'interest_rate': 1.3,
#         'monthly_amortization': 50556},
#        {'label': '2 years',
#         'is_default': 0,
#         'duration': 24,
#         'interest_rate': 1.29,
#         'monthly_amortization': 67580},
#        {'label': '1 year',
#         'is_default': 0,
#         'duration': 12,
#         'interest_rate': 1.3,
#         'monthly_amortization': 119683}],
#       'loan_amount': 1238101,
#       'downpayment': 530615,
#       'processing_fee': 86667,
#       'other_charges': 0},
#      {'rate_name': '40',
#       'rate_data': [{'label': '4 years',
#         'is_default': 1,
#         'duration': 48,
#         'interest_rate': 1.45,
#         'monthly_amortization': 37585},
#        {'label': '3 years',
#         'is_default': 0,
#         'duration': 36,
#         'interest_rate': 1.3,
#         'monthly_amortization': 43334},
#        {'label': '2 years',
#         'is_default': 0,
#         'duration': 24,
#         'interest_rate': 1.29,
#         'monthly_amortization': 57925},
#        {'label': '1 year',
#         'is_default': 0,
#         'duration': 12,
#         'interest_rate': 1.3,
#         'monthly_amortization': 102586}],
#       'loan_amount': 1061230,
#       'downpayment': 707486,
#       'processing_fee': 74286,
#       'other_charges': 0},
#      {'rate_name': '50',
#       'rate_data': [{'label': '4 years',
#         'is_default': 1,
#         'duration': 48,
#         'interest_rate': 1.45,
#         'monthly_amortization': 31321},
#        {'label': '3 years',
#         'is_default': 0,
#         'duration': 36,
#         'interest_rate': 1.3,
#         'monthly_amortization': 36111},
#        {'label': '2 years',
#         'is_default': 0,
#         'duration': 24,
#         'interest_rate': 1.29,
#         'monthly_amortization': 48271},
#        {'label': '1 year',
#         'is_default': 0,
#         'duration': 12,
#         'interest_rate': 1.3,
#         'monthly_amortization': 85488}],
#       'loan_amount': 884358,
#       'downpayment': 884358,
#       'processing_fee': 61905,
#       'other_charges': 0}],
#     'bid_terms': [{'rate_name': '20',
#       'rate_data': [{'label': '4 years',
#         'is_default': 1,
#         'duration': 48,
#         'interest_rate': 1.45,
#         'monthly_amortization': 48654},
#        {'label': '3 years',
#         'is_default': 0,
#         'duration': 36,
#         'interest_rate': 1.3,
#         'monthly_amortization': 56095},
#        {'label': '2 years',
#         'is_default': 0,
#         'duration': 24,
#         'interest_rate': 1.29,
#         'monthly_amortization': 74984},
#        {'label': '1 year',
#         'is_default': 0,
#         'duration': 12,
#         'interest_rate': 1.3,
#         'monthly_amortization': 132797}],
#       'loan_amount': 1373760,
#       'downpayment': 343440,
#       'processing_fee': 96163,
#       'other_charges': 0},
#      {'rate_name': '30',
#       'rate_data': [{'label': '4 years',
#         'is_default': 1,
#         'duration': 48,
#         'interest_rate': 1.45,
#         'monthly_amortization': 42572},
#        {'label': '3 years',
#         'is_default': 0,
#         'duration': 36,
#         'interest_rate': 1.3,
#         'monthly_amortization': 49083},
#        {'label': '2 years',
#         'is_default': 0,
#         'duration': 24,
#         'interest_rate': 1.29,
#         'monthly_amortization': 65611},
#        {'label': '1 year',
#         'is_default': 0,
#         'duration': 12,
#         'interest_rate': 1.3,
#         'monthly_amortization': 116197}],
#       'loan_amount': 1202040,
#       'downpayment': 515160,
#       'processing_fee': 84143,
#       'other_charges': 0},
#      {'rate_name': '40',
#       'rate_data': [{'label': '4 years',
#         'is_default': 1,
#         'duration': 48,
#         'interest_rate': 1.45,
#         'monthly_amortization': 36491},
#        {'label': '3 years',
#         'is_default': 0,
#         'duration': 36,
#         'interest_rate': 1.3,
#         'monthly_amortization': 42071},
#        {'label': '2 years',
#         'is_default': 0,
#         'duration': 24,
#         'interest_rate': 1.29,
#         'monthly_amortization': 56238},
#        {'label': '1 year',
#         'is_default': 0,
#         'duration': 12,
#         'interest_rate': 1.3,
#         'monthly_amortization': 99598}],
#       'loan_amount': 1030320,
#       'downpayment': 686880,
#       'processing_fee': 72122,
#       'other_charges': 0},
#      {'rate_name': '50',
#       'rate_data': [{'label': '4 years',
#         'is_default': 1,
#         'duration': 48,
#         'interest_rate': 1.45,
#         'monthly_amortization': 30409},
#        {'label': '3 years',
#         'is_default': 0,
#         'duration': 36,
#         'interest_rate': 1.3,
#         'monthly_amortization': 35060},
#        {'label': '2 years',
#         'is_default': 0,
#         'duration': 24,
#         'interest_rate': 1.29,
#         'monthly_amortization': 46865},
#        {'label': '1 year',
#         'is_default': 0,
#         'duration': 12,
#         'interest_rate': 1.3,
#         'monthly_amortization': 82998}],
#       'loan_amount': 858600,
#       'downpayment': 858600,
#       'processing_fee': 60102,
#       'other_charges': 0}]}}},
#  {'id': 55064,
#   'title': '2018 Hyundai H350 DLX  2.5',
#   'slug': 'neb5829',
#   'buy_now_price': 1635000,
#   'price': None,
#   'price_order': 1635000,
#   'is_featured': 0,
#   'view': 1030,
#   'winner_id': None,
#   'is_acuv': 0,
#   'is_repoz': 0,
#   'expired_at': '2024-06-28 06:20:00',
#   'car': {'odometer_reading': 46000,
#    'year_model': '2018',
#    'model': {'name': 'H350',
#     'transmission_type': 'MT',
#     'fuel_type': 'Diesel',
#     'vehicle_type': {'id': 5},
#     'make': {'name': 'Hyundai'}}},
#   'acuv_certification': None,
#   'warehouse': {'location': 'Baesa',
#    'has_financing': 1,
#    'city': {'city_name': 'Quezon City'},
#    'bank': {'id': 1,
#     'min_loan_amount': 260000,
#     'year_minus_count': 4,
#     'has_processing_fee': 0}},
#   'media_images': [{'id': 374448,
#     'user_id': 1,
#     'ad_id': 55064,
#     'post_id': None,
#     'media_name': 'used-Hyundai-H350-neb5829-374448.webp',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/neb5829/used-Hyundai-H350-neb5829-374448.webp',
#     'type': 'image',
#     'is_feature': '',
#     'storage': 'do_spaces',
#     'ref': 'ad',
# ...
#         'interest_rate': 0.83,
#         'monthly_amortization': 30422}],
#       'loan_amount': 609104,
#       'downpayment': 609104,
#       'processing_fee': 0,
#       'other_charges': 0},
#      {'rate_name': '20',
#       'rate_data': [{'label': '4 years',
#         'is_default': 1,
#         'duration': 48,
#         'interest_rate': 0.75,
#         'monthly_amortization': 28197},
#        {'label': '3 years',
#         'is_default': 0,
#         'duration': 36,
#         'interest_rate': 0.79,
#         'monthly_amortization': 34797},
#        {'label': '2 years',
#         'is_default': 0,
#         'duration': 24,
#         'interest_rate': 0.83,
#         'monthly_amortization': 48675}],
#       'loan_amount': 974566,
#       'downpayment': 243641,
#       'processing_fee': 0,
#       'other_charges': 0}],
#     'bid_terms': []}}},
#  {'id': 57750,
#   'title': '2019 Ford Ranger Raptor 4x4 2.0',
#   'slug': 'dan2648',
#   'buy_now_price': 1193000,
#   'price': None,
#   'price_order': 1193000,
#   'is_featured': 0,
#   'view': 397,
#   'winner_id': None,
#   'is_acuv': 0,
#   'is_repoz': 1,
#   'expired_at': '2024-06-28 09:50:00',
#   'car': {'odometer_reading': 52000,
#    'year_model': '2019',
#    'model': {'name': 'Ranger',
#     'transmission_type': 'AT',
#     'fuel_type': 'Diesel',
#     'vehicle_type': {'id': 6},
#     'make': {'name': 'Ford'}}},
#   'acuv_certification': None,
#   'warehouse': {'location': 'General Trias',
#    'has_financing': 0,
#    'city': {'city_name': 'Cavite'},
#    'bank': {'id': 1,
#     'min_loan_amount': 260000,
#     'year_minus_count': 4,
#     'has_processing_fee': 0}},
#   'media_images': [{'id': 378727,
#     'user_id': 1,
#     'ad_id': 57750,
#     'post_id': None,
#     'media_name': 'used-Ford-Ranger-dan2648-378727.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/dan2648/used-Ford-Ranger-dan2648-378727.jpg',
#     'type': 'image',
#     'is_feature': '1',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/dan2648/used-Ford-Ranger-dan2648-378727.png'},
#    {'id': 378728,
#     'user_id': 1,
#     'ad_id': 57750,
#     'post_id': None,
#     'media_name': 'used-Ford-Ranger-dan2648-378728.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/dan2648/used-Ford-Ranger-dan2648-378728.jpg',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/dan2648/used-Ford-Ranger-dan2648-378728.png'},
#    {'id': 378729,
#     'user_id': 1,
#     'ad_id': 57750,
#     'post_id': None,
#     'media_name': 'used-Ford-Ranger-dan2648-378729.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/dan2648/used-Ford-Ranger-dan2648-378729.jpg',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/dan2648/used-Ford-Ranger-dan2648-378729.png'},
#    {'id': 378730,
#     'user_id': 1,
#     'ad_id': 57750,
#     'post_id': None,
#     'media_name': 'used-Ford-Ranger-dan2648-378730.jpg',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/dan2648/used-Ford-Ranger-dan2648-378730.jpg',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/dan2648/used-Ford-Ranger-dan2648-378730.png'}],
#   'first_media_image': {'id': 378727,
#    'user_id': 1,
#    'ad_id': 57750,
#    'post_id': None,
#    'media_name': 'used-Ford-Ranger-dan2648-378727.jpg',
#    'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/dan2648/used-Ford-Ranger-dan2648-378727.jpg',
#    'type': 'image',
#    'is_feature': '1',
#    'storage': 'do_spaces',
#    'ref': 'ad',
#    'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/dan2648/used-Ford-Ranger-dan2648-378727.png'},
#   'featured_media_image': {'id': 378727,
#    'user_id': 1,
#    'ad_id': 57750,
#    'post_id': None,
#    'media_name': 'used-Ford-Ranger-dan2648-378727.jpg',
#    'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/dan2648/used-Ford-Ranger-dan2648-378727.jpg',
#    'type': 'image',
#    'is_feature': '1',
#    'storage': 'do_spaces',
#    'ref': 'ad',
#    'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/dan2648/used-Ford-Ranger-dan2648-378727.png'},
#   'top_bid': None,
#   'installment_terms': {'status': False,
#    'message': 'financing not available'}},
#  {'id': 57183,
#   'title': '2022 Mitsubishi Strada 4x4 2.4',
#   'slug': 'y0h122',
#   'buy_now_price': 1191743,
#   'price': None,
#   'price_order': 1191743,
#   'is_featured': 0,
#   'view': 569,
#   'winner_id': None,
#   'is_acuv': 0,
#   'is_repoz': 1,
#   'expired_at': '2024-06-26 16:00:00',
#   'car': {'odometer_reading': 10249,
#    'year_model': '2022',
#    'model': {'name': 'Strada',
#     'transmission_type': 'AT',
#     'fuel_type': 'Diesel',
#     'vehicle_type': {'id': 6},
#     'make': {'name': 'Mitsubishi'}}},
#   'acuv_certification': None,
#   'warehouse': {'location': 'Oriental',
#    'has_financing': 1,
#    'city': {'city_name': 'Cebu'},
#    'bank': {'id': 3,
#     'min_loan_amount': 370000,
#     'year_minus_count': 60,
#     'has_processing_fee': 0}},
#   'media_images': [{'id': 375573,
#     'user_id': 1,
#     'ad_id': 57183,
#     'post_id': None,
#     'media_name': 'used-Mitsubishi-Strada-y0h122-375573.webp',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/y0h122/used-Mitsubishi-Strada-y0h122-375573.webp',
#     'type': 'image',
#     'is_feature': '1',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/y0h122/used-Mitsubishi-Strada-y0h122-375573.png'},
#    {'id': 375574,
#     'user_id': 1,
#     'ad_id': 57183,
#     'post_id': None,
#     'media_name': 'used-Mitsubishi-Strada-y0h122-375574.webp',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/y0h122/used-Mitsubishi-Strada-y0h122-375574.webp',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/y0h122/used-Mitsubishi-Strada-y0h122-375574.png'},
#    {'id': 375575,
#     'user_id': 1,
#     'ad_id': 57183,
#     'post_id': None,
#     'media_name': 'used-Mitsubishi-Strada-y0h122-375575.webp',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/y0h122/used-Mitsubishi-Strada-y0h122-375575.webp',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/y0h122/used-Mitsubishi-Strada-y0h122-375575.png'},
#    {'id': 375576,
#     'user_id': 1,
#     'ad_id': 57183,
#     'post_id': None,
#     'media_name': 'used-Mitsubishi-Strada-y0h122-375576.webp',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/y0h122/used-Mitsubishi-Strada-y0h122-375576.webp',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/y0h122/used-Mitsubishi-Strada-y0h122-375576.png'},
#    {'id': 375577,
#     'user_id': 1,
#     'ad_id': 57183,
#     'post_id': None,
#     'media_name': 'used-Mitsubishi-Strada-y0h122-375577.webp',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/y0h122/used-Mitsubishi-Strada-y0h122-375577.webp',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/y0h122/used-Mitsubishi-Strada-y0h122-375577.png'},
#    {'id': 375578,
#     'user_id': 1,
#     'ad_id': 57183,
#     'post_id': None,
#     'media_name': 'used-Mitsubishi-Strada-y0h122-375578.webp',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/y0h122/used-Mitsubishi-Strada-y0h122-375578.webp',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/y0h122/used-Mitsubishi-Strada-y0h122-375578.png'},
#    {'id': 375579,
#     'user_id': 1,
#     'ad_id': 57183,
#     'post_id': None,
#     'media_name': 'used-Mitsubishi-Strada-y0h122-375579.webp',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/y0h122/used-Mitsubishi-Strada-y0h122-375579.webp',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/y0h122/used-Mitsubishi-Strada-y0h122-375579.png'}],
#   'first_media_image': {'id': 375573,
#    'user_id': 1,
#    'ad_id': 57183,
#    'post_id': None,
#    'media_name': 'used-Mitsubishi-Strada-y0h122-375573.webp',
#    'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/y0h122/used-Mitsubishi-Strada-y0h122-375573.webp',
#    'type': 'image',
#    'is_feature': '1',
#    'storage': 'do_spaces',
#    'ref': 'ad',
#    'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/y0h122/used-Mitsubishi-Strada-y0h122-375573.png'},
#   'featured_media_image': {'id': 375573,
#    'user_id': 1,
#    'ad_id': 57183,
#    'post_id': None,
#    'media_name': 'used-Mitsubishi-Strada-y0h122-375573.webp',
#    'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/y0h122/used-Mitsubishi-Strada-y0h122-375573.webp',
#    'type': 'image',
#    'is_feature': '1',
#    'storage': 'do_spaces',
#    'ref': 'ad',
#    'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/y0h122/used-Mitsubishi-Strada-y0h122-375573.png'},
#   'top_bid': None,
#   'installment_terms': {'status': True,
#    'message': 'financing available',
#    'data': {'buy_terms': [{'rate_name': '30',
#       'rate_data': [{'label': '4 years',
#         'is_default': 1,
#         'duration': 48,
#         'interest_rate': 0.75,
#         'monthly_amortization': 24137},
#        {'label': '3 years',
#         'is_default': 0,
#         'duration': 36,
#         'interest_rate': 0.79,
#         'monthly_amortization': 29786},
#        {'label': '2 years',
#         'is_default': 0,
#         'duration': 24,
#         'interest_rate': 0.83,
#         'monthly_amortization': 41666}],
#       'loan_amount': 834220,
#       'downpayment': 357523,
#       'processing_fee': 0,
#       'other_charges': 0},
#      {'rate_name': '40',
#       'rate_data': [{'label': '4 years',
#         'is_default': 1,
#         'duration': 48,
#         'interest_rate': 0.75,
#         'monthly_amortization': 20689},
#        {'label': '3 years',
#         'is_default': 0,
#         'duration': 36,
#         'interest_rate': 0.79,
#         'monthly_amortization': 25531},
#        {'label': '2 years',
#         'is_default': 0,
#         'duration': 24,
#         'interest_rate': 0.83,
#         'monthly_amortization': 35714}],
#       'loan_amount': 715046,
#       'downpayment': 476697,
#       'processing_fee': 0,
#       'other_charges': 0},
#      {'rate_name': '50',
#       'rate_data': [{'label': '4 years',
#         'is_default': 1,
#         'duration': 48,
#         'interest_rate': 0.75,
#         'monthly_amortization': 17241},
#        {'label': '3 years',
#         'is_default': 0,
#         'duration': 36,
#         'interest_rate': 0.79,
#         'monthly_amortization': 21276},
#        {'label': '2 years',
#         'is_default': 0,
#         'duration': 24,
#         'interest_rate': 0.83,
#         'monthly_amortization': 29761}],
#       'loan_amount': 595872,
#       'downpayment': 595872,
#       'processing_fee': 0,
#       'other_charges': 0},
#      {'rate_name': '20',
#       'rate_data': [{'label': '4 years',
#         'is_default': 1,
#         'duration': 48,
#         'interest_rate': 0.75,
#         'monthly_amortization': 27585},
#        {'label': '3 years',
#         'is_default': 0,
#         'duration': 36,
#         'interest_rate': 0.79,
#         'monthly_amortization': 34041},
#        {'label': '2 years',
#         'is_default': 0,
#         'duration': 24,
#         'interest_rate': 0.83,
#         'monthly_amortization': 47618}],
#       'loan_amount': 953394,
#       'downpayment': 238349,
#       'processing_fee': 0,
#       'other_charges': 0}],
#     'bid_terms': []}}},
#  {'id': 54403,
#   'title': '2018 Ford Everest Titanium 4x4 3.2',
#   'slug': 'daj1060',
#   'buy_now_price': 1188000,
#   'price': None,
#   'price_order': 1188000,
#   'is_featured': 0,
#   'view': 1126,
#   'winner_id': None,
#   'is_acuv': 0,
#   'is_repoz': 1,
#   'expired_at': '2024-06-28 09:50:00',
#   'car': {'odometer_reading': 58000,
#    'year_model': '2018',
#    'model': {'name': 'Everest',
#     'transmission_type': 'AT',
#     'fuel_type': 'Diesel',
#     'vehicle_type': {'id': 4},
#     'make': {'name': 'Ford'}}},
#   'acuv_certification': None,
#   'warehouse': {'location': 'Mall of Asia',
#    'has_financing': 0,
#    'city': {'city_name': 'Pasay'},
#    'bank': {'id': 1,
#     'min_loan_amount': 260000,
#     'year_minus_count': 4,
#     'has_processing_fee': 0}},
#   'media_images': [{'id': 374956,
#     'user_id': 1,
#     'ad_id': 54403,
#     'post_id': None,
#     'media_name': 'used-Ford-Everest-daj1060-374956.webp',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/daj1060/used-Ford-Everest-daj1060-374956.webp',
#     'type': 'image',
#     'is_feature': '',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/daj1060/used-Ford-Everest-daj1060-374956.png'},
#    {'id': 374957,
#     'user_id': 1,
#     'ad_id': 54403,
#     'post_id': None,
#     'media_name': 'used-Ford-Everest-daj1060-374957.webp',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/daj1060/used-Ford-Everest-daj1060-374957.webp',
#     'type': 'image',
#     'is_feature': '1',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/daj1060/used-Ford-Everest-daj1060-374957.png'},
#    {'id': 374958,
#     'user_id': 1,
#     'ad_id': 54403,
#     'post_id': None,
#     'media_name': 'used-Ford-Everest-daj1060-374958.webp',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/daj1060/used-Ford-Everest-daj1060-374958.webp',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/daj1060/used-Ford-Everest-daj1060-374958.png'},
#    {'id': 374959,
#     'user_id': 1,
#     'ad_id': 54403,
#     'post_id': None,
#     'media_name': 'used-Ford-Everest-daj1060-374959.webp',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/daj1060/used-Ford-Everest-daj1060-374959.webp',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/daj1060/used-Ford-Everest-daj1060-374959.png'},
#    {'id': 374960,
#     'user_id': 1,
#     'ad_id': 54403,
#     'post_id': None,
#     'media_name': 'used-Ford-Everest-daj1060-374960.webp',
#     'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/daj1060/used-Ford-Everest-daj1060-374960.webp',
#     'type': 'image',
#     'is_feature': '0',
#     'storage': 'do_spaces',
#     'ref': 'ad',
#     'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/daj1060/used-Ford-Everest-daj1060-374960.png'}],
#   'first_media_image': {'id': 374956,
#    'user_id': 1,
#    'ad_id': 54403,
#    'post_id': None,
#    'media_name': 'used-Ford-Everest-daj1060-374956.webp',
#    'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/daj1060/used-Ford-Everest-daj1060-374956.webp',
#    'type': 'image',
#    'is_feature': '',
#    'storage': 'do_spaces',
#    'ref': 'ad',
#    'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/daj1060/used-Ford-Everest-daj1060-374956.png'},
#   'featured_media_image': {'id': 374957,
#    'user_id': 1,
#    'ad_id': 54403,
#    'post_id': None,
#    'media_name': 'used-Ford-Everest-daj1060-374957.webp',
#    'url': 'https://automart-dev.sgp1.digitaloceanspaces.com/daj1060/used-Ford-Everest-daj1060-374957.webp',
#    'type': 'image',
#    'is_feature': '1',
#    'storage': 'do_spaces',
#    'ref': 'ad',
#    'catalog_image_url': 'https://automart-dev.sgp1.digitaloceanspaces.com/daj1060/used-Ford-Everest-daj1060-374957.png'},
#   'top_bid': None,
#   'installment_terms': {'status': False,
#    'message': 'financing not available'}}]

# %%
url_body = r"https://api.automart.ph/vehicle-types?status=1"
body_content = requests.get(url_body).json()
body_content
# Out:
# [{'id': 4,
#   'name': 'SUV',
#   'label': 'SUV',
#   'image': 'https://automart-dev.sgp1.digitaloceanspaces.com/assets/vehicle_types/used-car-type-suv.webp',
#   'status': 1,
#   'sequence_order': 1,
#   'created_at': '2019-08-02T10:56:16.000Z',
#   'updated_at': '2021-12-14T23:33:03.000Z'},
#  {'id': 3,
#   'name': 'Sedan',
#   'label': 'Sedan',
#   'image': 'https://automart-dev.sgp1.digitaloceanspaces.com/assets/vehicle_types/used-car-type-sedan.webp',
#   'status': 1,
#   'sequence_order': 2,
#   'created_at': '2019-08-02T10:56:16.000Z',
#   'updated_at': '2021-12-14T23:33:03.000Z'},
#  {'id': 1,
#   'name': 'AUV',
#   'label': 'AUV / MPV / FB',
#   'image': 'https://automart-dev.sgp1.digitaloceanspaces.com/assets/vehicle_types/used-car-type-auv.webp',
#   'status': 1,
#   'sequence_order': 3,
#   'created_at': '2019-08-02T10:56:16.000Z',
#   'updated_at': '2021-12-14T23:33:03.000Z'},
#  {'id': 6,
#   'name': 'Pickup',
#   'label': 'Pickup Trucks',
#   'image': 'https://automart-dev.sgp1.digitaloceanspaces.com/assets/vehicle_types/used-car-type-trucks.webp',
#   'status': 1,
#   'sequence_order': 4,
#   'created_at': '2019-10-04T08:42:56.000Z',
#   'updated_at': '2021-12-14T23:33:03.000Z'},
#  {'id': 2,
#   'name': 'Hatchback',
#   'label': 'Hatchback',
#   'image': 'https://automart-dev.sgp1.digitaloceanspaces.com/assets/vehicle_types/used-car-type-hatchback.webp',
#   'status': 1,
#   'sequence_order': 5,
#   'created_at': '2019-08-02T10:56:16.000Z',
#   'updated_at': '2021-12-14T23:33:03.000Z'},
#  {'id': 5,
#   'name': 'Van',
#   'label': 'Van',
#   'image': 'https://automart-dev.sgp1.digitaloceanspaces.com/assets/vehicle_types/used-car-type-van.webp',
#   'status': 1,
#   'sequence_order': 6,
#   'created_at': '2019-08-02T10:56:16.000Z',
#   'updated_at': '2021-12-14T23:33:03.000Z'}]

# %%
# Get Body Types

url_body = r"https://api.automart.ph/vehicle-types?status=1"
body_type = {item["id"]: item["name"] for item in requests.get(url_body).json()}
body_type[9] = "MPV"
body_type[11] = "Truck"
body_type
# Out:
# {4: 'SUV',
#  3: 'Sedan',
#  1: 'AUV',
#  6: 'Pickup',
#  2: 'Hatchback',
#  5: 'Van',
#  9: 'MPV',
#  11: 'Truck'}

# %%
# Count pages

url_pages = r"https://api.automart.ph/products?fields=%7B%22id%22:%22id%22%7D&limit=1&product_category_id=1"
pages = requests.get(url_pages).json()
count = pages["meta"]["totalItems"]/24
count = int(count) if count % 1 == 0 else int(count) + 1
count
# Out:
# 47

# %%
def automart(url):
  content_html = requests.get(url)
  content = content_html.json()

  am_df = [{"MAKE": item["car"]["model"]["make"]["name"],
            "MODEL": item["car"]["model"]["name"],
            "YEAR": item["car"]["year_model"],
             "TITLE": item["title"].replace(item["car"]["year_model"], ""),
            "TRANSMISSION": item["car"]["model"]["transmission_type"],
            "BODY": body_type.get(item["car"]["model"]["vehicle_type"]["id"]),
            "PRICE": item["price_order"],
            "LOCATION": f"{item['warehouse']['location']}, {item['warehouse']['city']['city_name']}",
            "MILEAGE": item["car"]["odometer_reading"],
            "FUEL TYPE": item["car"]["model"]["fuel_type"] } for item in content["items"]]
  return(pd.DataFrame.from_dict(am_df))


dfs = []
for i in range(1, count + 1):
  url_am = f'https://api.automart.ph/products?page={i}&limit=24'

  df = automart(url_am).drop_duplicates().reset_index(drop=True)
  dfs.append(df)


all_df = pd.concat(dfs)

# Reset Index
all_df.index = np.arange(0, len(all_df))

all_df
# Out:
#                MAKE    MODEL  YEAR                       TITLE TRANSMISSION  \
# 0             Lexus    RX350  2018      Lexus RX350 Sport  3.5           AT
# 1             Volvo      X40  2020            Volvo X40 T5 2.0           AT
# 2              Ford  Mustang  2016      Ford Mustang V6 Coupe            AT
# 3     Mercedes Benz     C250  2016   Mercedes Benz C250 Coupe            AT
# 4          Mercedes     Benz  2011      Mercedes Benz S350 3.5           AT
# ...             ...      ...   ...                         ...          ...
# 1105        Hyundai   Accent  2020       Hyundai Accent GL 1.4           AT
# 1106         Nissan   Almera  2015      Nissan Almera Base 1.5           MT
# 1107        Hyundai   Accent  2015        Hyundai Accent E 1.4           MT
# 1108        Hyundai      Eon  2016         Hyundai Eon GLS 0.8           MT
# 1109         Nissan   Almera  2018      Nissan Almera Base 1.2           MT
#
#        BODY    PRICE                   LOCATION   MILEAGE FUEL TYPE
# 0     Sedan  3195000         Baesa, Quezon City   77000.0       Gas
# 1       SUV  2343000         Baesa, Quezon City    9000.0       Gas
# 2     Sedan  2226000      Dacudao Avenue, Davao   23509.0       Gas
# 3     Sedan  2024000         Baesa, Quezon City   43000.0       Gas
# 4       Van  1836450  Kalayaan Ave, Quezon City   27000.0       Gas
# ...     ...      ...                        ...       ...       ...
# 1105  Sedan   183154         Sanford, Parañaque       NaN       Gas
# 1106  Sedan   181300             Bunawan, Davao  120897.0       Gas
# 1107  Sedan   181220         Sanford, Parañaque   64137.0       Gas
# 1108  Sedan   162400  Festival Mall, Muntinlupa   56816.0       Gas
# 1109  Sedan   143000             Bunawan, Davao       NaN       Gas
#
# [1110 rows x 10 columns]

# %%
all_df.shape
# Out:
# (1110, 10)

# %%
all_df[all_df["MILEAGE"].isna()]
# Out:
#             MAKE      MODEL  YEAR                              TITLE  \
# 223       Suzuki     Ertiga  2022               Suzuki Ertiga GL 1.5
# 276         Ford     Ranger  2019            Ford Ranger XLT 4x2 2.2
# 278         Ford     Ranger  2019            Ford Ranger XLT 4x2 2.2
# 340       Toyota     Hi-Ace  2019   Toyota Hi-Ace EL Commuter XE 2.8
# 402        Geely    EMGRAND  2023    GEELY  EMGRAND EL Premium G 1.5
# 433         Ford    Everest  2017         Ford Everest Trend 4x2 2.2
# 449        Mazda       CX-3  2018                    Mazda CX-3  2.0
# 515      Hyundai       HD36  2020                 Hyundai HD36   2.5
# 566       Toyota       Wigo  2019                 Toyota Wigo G  1.0
# 578        Honda       City  2019                   Honda City E 1.5
# 599   Mitsubishi    Xpander  2023   Mitsubishi Xpander GLX G 4x2 1.5
# 601         Ford   Ecosport  2016         Ford Ecosport Titanium 1.5
# 602         Ford     Ranger  2020            Ford Ranger XLT 4x2 2.2
# 611       Toyota     Avanza  2018                Toyota Avanza E 1.3
# 626         Ford   Ecosport  2016            Ford Ecosport Trend 1.5
# 642       Suzuki     Ertiga  2018               Suzuki Ertiga GL 1.4
# 645       Suzuki      Carry  2020                     Suzuki Carry
# 646       Toyota     Hi-Ace  2019         Toyota Hi-Ace Commuter 3.0
# 650         Ford   Ecosport  2016         Ford Ecosport Ambiente 1.5
# 656         Ford   Ecosport  2017            Ford Ecosport Trend 1.5
# 662         Ford     Fiesta  2016    Ford Fiesta Hatchback Sport 1.0
# 667      Hyundai     Accent  2016               Hyundai Accent E 1.6
# 672       Nissan     Almera  2018                Nissan Almera E 1.5
# 729       Nissan     Navara  2023              Nissan Navara 4x4 2.5
# 774       Nissan      Terra  2020            Nissan Terra VE 4x2 2.5
# 798       Nissan     Navara  2021           Nissan Navara VE 4x2 2.5
# 859       Nissan     Navara  2019     Nissan Navara NP300 VL 4x4 2.5
# 923         Ford     Ranger  2020            Ford Ranger XLS 4x2 2.2
# 928       Nissan     Navara  2019     Nissan Navara NP300 EL 4x2 2.5
# 929         Ford     Ranger  2019       Ford Ranger Wildtrak 4x2 2.0
# 943   Mitsubishi       L300  2022               Mitsubishi L300  2.2
# 952       Suzuki      Dzire  2022                     Suzuki Dzire
# 962   Mitsubishi  Mirage G4  2023     Mitsubishi Mirage G4 GLX G 1.2
# 1018        Ford     Ranger  2018          Ford Ranger Wildtrak 4x4
# 1078       Mazda       BT50  2016                 Mazda BT50 4x2 2.2
# 1095  Mitsubishi  Mirage G4  2017     Mitsubishi Mirage G4 GLS G 1.2
# 1105     Hyundai     Accent  2020              Hyundai Accent GL 1.4
# 1109      Nissan     Almera  2018             Nissan Almera Base 1.2
#
#      TRANSMISSION       BODY   PRICE                       LOCATION  MILEAGE  \
# 223            AT        MPV  641784             Sanford, Parañaque      NaN
# 276            AT     Pickup  596800             Sanford, Parañaque      NaN
# 278            AT     Pickup  595200             Sanford, Parañaque      NaN
# 340            MT        Van  550800             Sanford, Parañaque      NaN
# 402            AT      Sedan  505096        Bagumbayan, Taguig City      NaN
# 433            AT        SUV  484653                 Oriental, Cebu      NaN
# 449            AT        SUV  474874             Sanford, Parañaque      NaN
# 515            MT        Van  413400        Bagumbayan, Taguig City      NaN
# 566            AT  Hatchback  352000          General Trias, Cavite      NaN
# 578            MT      Sedan  336000                 Bunawan, Davao      NaN
# 599            AT        MPV  300600             Sanford, Parañaque      NaN
# 601            AT        SUV  298792  Filinvest Alabang, Muntinlupa      NaN
# 602            AT     Pickup  298350        Bagumbayan, Taguig City      NaN
# 611            MT        MPV  279000                Tingub, Mandaue      NaN
# 626            MT        SUV  252658             Bicutan, Parañaque      NaN
# 642            AT        MPV  225531             Sanford, Parañaque      NaN
# 645            MT        Van  220779                Tingub, Mandaue      NaN
# 646            MT        Van  217750             Sanford, Parañaque      NaN
# 650            MT        SUV  209619             Bicutan, Parañaque      NaN
# 656            AT        SUV  198955             Sanford, Parañaque      NaN
# 662            AT  Hatchback  149500             Sanford, Parañaque      NaN
# 667            MT      Sedan  134400                 Bunawan, Davao      NaN
# 672            MT      Sedan   56000                 Bunawan, Davao      NaN
# 729            AT     Pickup  989030                 Bunawan, Davao      NaN
# 774            AT        SUV  820000                 Bunawan, Davao      NaN
# 798            AT     Pickup  775200                 Bunawan, Davao      NaN
# 859            MT     Pickup  658400                 Bunawan, Davao      NaN
# 923            AT     Pickup  582250             Sanford, Parañaque      NaN
# 928            AT     Pickup  576800                 Bunawan, Davao      NaN
# 929            AT     Pickup  575484                 Bunawan, Davao      NaN
# 943            MT        Van  553350             Bicutan, Parañaque      NaN
# 952            MT      Sedan  535500                 Oriental, Cebu      NaN
# 962            AT      Sedan  523162             Sanford, Parañaque      NaN
# 1018           MT     Pickup  424800                 Bunawan, Davao      NaN
# 1078           AT     Pickup  302400                 Bunawan, Davao      NaN
# 1095           MT      Sedan  230116             Sanford, Parañaque      NaN
# 1105           AT      Sedan  183154             Sanford, Parañaque      NaN
# 1109           MT      Sedan  143000                 Bunawan, Davao      NaN
#
#      FUEL TYPE
# 223     Diesel
# 276     Diesel
# 278     Diesel
# 340     Diesel
# 402        Gas
# 433     Diesel
# 449        Gas
# 515     Diesel
# 566        Gas
# 578        Gas
# 599        Gas
# 601        Gas
# 602     Diesel
# 611     Diesel
# 626        Gas
# 642     Diesel
# 645     Diesel
# 646     Diesel
# 650        Gas
# 656        Gas
# 662        Gas
# 667        Gas
# 672        Gas
# 729     Diesel
# 774     Diesel
# 798     Diesel
# 859     Diesel
# 923     Diesel
# 928     Diesel
# 929     Diesel
# 943     Diesel
# 952        Gas
# 962        Gas
# 1018    Diesel
# 1078    Diesel
# 1095       Gas
# 1105       Gas
# 1109       Gas

# %%
all_df.dtypes
# Out:
# MAKE             object
# MODEL            object
# YEAR             object
# TITLE            object
# TRANSMISSION     object
# BODY             object
# PRICE             int64
# LOCATION         object
# MILEAGE         float64
# FUEL TYPE        object
# dtype: object

# %%
all_df.to_parquet(r"/content/drive/MyDrive/2024 BIP DIP & AGSIP/Web Scraping/JD_automart.parquet")
